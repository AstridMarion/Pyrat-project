# %% [markdown]
# <h1 style="background-color: gray;
#            color: black;
#            padding: 20px;
#            text-align: center;">INFO</h1>
#
# In this script, we run player `BFS` in a maze, to visualize its behavior.

# %% [markdown]
# <h1 style="background-color: gray;
#            color: black;
#            padding: 20px;
#            text-align: center;">IMPORTS</h1>

# %%
# External imports
import sys
import os
import pprint

# Add needed directories to the path
sys.path.append(os.path.join("..", "players"))

# PyRat imports
from pyrat import Game, GameMode
from BFS import BFS

# %% [markdown]
# <h1 style="background-color: gray;
#            color: black;
#            padding: 20px;
#            text-align: center;">CONSTANTS</h1>
#
# Let's configure the game with a dictionary.

# %%
# Customize the game elements
CONFIG = {"mud_percentage": 0.0,
          "nb_cheese": 1,
          "random_seed": 42,
          "trace_length": 1000,
          "game_mode": GameMode.SEQUENTIAL}

# %% [markdown]
# <h1 style="background-color: gray;
#            color: black;
#            padding: 20px;
#            text-align: center;">RUN THE GAME</h1>

# %% [markdown]
# We perform a single game with the configuration defined above.

# %%
# Instantiate a game with specified arguments
game = Game(**CONFIG)

# Instantiate a player and add it to the game
player = BFS()
game.add_player(player)

# Start the game
stats = game.start()
# Out:
# Constructor
# Preprocessing
# Preprocessing
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Player BFS has crashed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\astri\AppData\Roaming\Python\Python312\site-packages\pyrat\src\Game.py", line 881, in _player_process_function
#     a = player.turn(maze, game_state)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\astri\OneDrive\Documents\IMTA\IMTS5\informatique\pyrat_workspace\games\..\players\BFS.py", line 118, in turn
#     action = self.actions.pop(0)
#              ^^^^^^^^^^^^^^^^^^^
# IndexError: pop from empty list
#
# Traceback (most recent call last):
#   File "C:\Users\astri\AppData\Roaming\Python\Python312\site-packages\pyrat\src\Game.py", line 568, in start
#     raise Exception("A player has crashed, exiting")
# Exception: A player has crashed, exiting

# %% [markdown]
# We visualize results using a pretty printer.

# %%
# Show statistics
pprint.pprint(stats)
# Out:
# {}
